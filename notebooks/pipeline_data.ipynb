# %%
pip install transformers torch
# Out:
# Collecting transformers
#   Downloading transformers-5.3.0-py3-none-any.whl.metadata (32 kB)
# Collecting torch
#   Downloading torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.7.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/aurele/ESILV_S2/Information_Retrieval_and_NLP/project 2/project_2/venv_NLPSL/lib/python3.13/site-packages (from transformers) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Users/aurele/ESILV_S2/Information_Retrieval_and_NLP/project 2/project_2/venv_NLPSL/lib/python3.13/site-packages (from transformers) (26.0)
# Collecting pyyaml>=5.1 (from transformers)
#   Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2026.2.28-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typer (from transformers)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached hf_xet-1.4.2-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.1.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting setuptools<82 (from torch)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting click>=8.2.1 (from typer->transformers)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/aurele/ESILV_S2/Information_Retrieval_and_NLP/project 2/project_2/venv_NLPSL/lib/python3.13/site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.3.0-py3-none-any.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 745.4 kB/s  0:00:14a 0:00:010:00:0104
# Downloading huggingface_hub-1.7.2-py3-none-any.whl (618 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.0/618.0 kB 634.6 kB/s  0:00:01? eta -:--:--
# Using cached hf_xet-1.4.2-cp37-abi3-macosx_11_0_arm64.whl (3.6 MB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Downloading torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl (80.6 MB)
#    ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/80.6 MB 517.3 kB/s eta 0:01:55
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (21.5 MB/80.6 MB, attempt 1)
# Resuming download torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl (21.5 MB/80.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 MB 29.0 MB/s  0:00:020.0 MB/s eta 0:00:01:01
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.0 MB/s  0:00:00
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached regex-2026.2.28-cp313-cp313-macosx_11_0_arm64.whl (289 kB)
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, typing-extensions, tqdm, sympy, shellingham, setuptools, safetensors, regex, pyyaml, networkx, mdurl, MarkupSafe, idna, hf-xet, h11, fsspec, filelock, click, certifi, annotated-doc, markdown-it-py, jinja2, httpcore, anyio, torch, rich, httpx, typer, huggingface-hub, tokenizers, transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31/31 [transformers]7m━ 30/31 [transformers]y]
# Successfully installed MarkupSafe-3.0.3 annotated-doc-0.0.4 anyio-4.12.1 certifi-2026.2.25 click-8.3.1 filelock-3.25.2 fsspec-2026.2.0 h11-0.16.0 hf-xet-1.4.2 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.7.2 idna-3.11 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 pyyaml-6.0.3 regex-2026.2.28 rich-14.3.3 safetensors-0.7.0 setuptools-81.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.11.0 tqdm-4.67.3 transformers-5.3.0 typer-0.24.1 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline

corrector = pipeline(
    "text2text-generation",
    model="fdemelo/t5-base-spell-correction-fr"
)
